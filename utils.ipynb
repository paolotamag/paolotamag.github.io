# %%
import json

with open('collected_data.json') as f:
    json_dict = json.load(f)

# %%
image_links = []
for r in json_dict['review']:
    link_photo = r['profile_image_link']
    image_links.append(link_photo)

# %%
import requests
import os
import random
import time
from urllib.parse import urlparse
import shutil

def copy_default_image(default_image_path, save_path):
    """
    Copies the default logo image to the destination path.
    
    Args:
        default_image_path (str): Path to the default logo image
        save_path (str): Destination path for the copied image
        
    Returns:
        bool: True if successful, False if failed
    """
    try:
        shutil.copy2(default_image_path, save_path)
        print(f"Used default logo image instead")
        return True
    except Exception as e:
        print(f"Error copying default image: {str(e)}")
        return False

def download_image(url, save_folder, default_image_path):
    """
    Downloads an image from a URL and saves it to the specified folder.
    If download fails, uses the default logo image instead.
    
    Args:
        url (str): URL of the image to download
        save_folder (str): Path to the folder where images will be saved
        default_image_path (str): Path to the default logo image
    
    Returns:
        bool: True if successful (either download or default image), False if all failed
    """
    try:
        # Create the save folder if it doesn't exist
        if not os.path.exists(save_folder):
            os.makedirs(save_folder)
            
        # Get the filename from the URL
        filename = os.path.basename(urlparse(url).path)+".jpg"
            
        # Full path for saving the image
        save_path = os.path.join(save_folder, filename)
        
        # Check if file already exists
        if os.path.exists(save_path):
            print(f"Skipping {filename} - File already exists")
            return True
            
        # Try to download the image
        try:
            response = requests.get(url, stream=True)
            response.raise_for_status()  # Raise an exception for bad status codes
            
            # Save the image
            with open(save_path, 'wb') as f:
                for chunk in response.iter_content(chunk_size=8192):
                    if chunk:
                        f.write(chunk)
                        
            print(f"Successfully downloaded: {filename}")
            return True
            
        except Exception as download_error:
            print(f"Error downloading image from {url}: {str(download_error)}")
            print("Using default logo instead...")
            return copy_default_image(default_image_path, save_path)
            
    except Exception as e:
        print(f"Unexpected error: {str(e)}")
        return False

def batch_download_images(urls, save_folder, default_image_path):
    """
    Downloads multiple images with random delays between downloads.
    Uses default logo image when downloads fail.
    
    Args:
        urls (list): List of image URLs to download
        save_folder (str): Path to the folder where images will be saved
        default_image_path (str): Path to the default logo image
    """
    # Verify default image exists
    if not os.path.exists(default_image_path):
        raise FileNotFoundError(f"Default image not found at: {default_image_path}")
    
    # Keep track of downloads and skips
    total_urls = len(urls)
    downloaded = 0
    skipped = 0
    default_used = 0
    
    for i, url in enumerate(urls, 1):
        print(f"\nProcessing image {i} of {total_urls}")
        
        # Check if the file exists before downloading
        filename = os.path.basename(urlparse(url).path)+".jpg"
        
        save_path = os.path.join(save_folder, filename)
        
        if os.path.exists(save_path):
            print(f"Skipping {filename} - File already exists")
            skipped += 1
        else:
            # Try to download the image
            result = download_image(url, save_folder, default_image_path)
            if result:
                if os.path.getsize(save_path) == os.path.getsize(default_image_path):
                    default_used += 1
                else:
                    downloaded += 1
            
            # Random delay between 1 and 2 seconds (skip delay for last image)
            if i < total_urls:
                delay = random.uniform(1, 2)
                print(f"Waiting {delay:.2f} seconds...")
                time.sleep(delay)
    
    # Print summary
    print(f"\nDownload Summary:")
    print(f"Total URLs processed: {total_urls}")
    print(f"Successfully downloaded: {downloaded}")
    print(f"Default logo used: {default_used}")
    print(f"Skipped (already existed): {skipped}")
    print(f"Failed: {total_urls - downloaded - skipped - default_used}")

# %%
# Specify your save folder
save_folder = "reviews_images_avatars"

# Download the images
batch_download_images(image_links, save_folder, "avatar_placeholder.jpg")
# Out:
# Processing image 1 of 20
# Skipping 1700444650829.jpg - File already exists
#
# Processing image 2 of 20
# Skipping 1517286449740.jpg - File already exists
#
# Processing image 3 of 20
# Skipping 1517019548162.jpg - File already exists
#
# Processing image 4 of 20
# Skipping 1549211827567.jpg - File already exists
#
# Processing image 5 of 20
# Skipping 1529332164858.jpg - File already exists
#
# Processing image 6 of 20
# Skipping 1721652770867.jpg - File already exists
#
# Processing image 7 of 20
# Error downloading image from https://media.licdn.com/dms/image/v2/D4E03AQHhA1NMl9r1_A/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1698670021775?e=1736985600&v=beta&t=pW0L9VLPufUGVLEFRr0uQTWCCy2IawxFmI-MCRnfw2: 403 Client Error: Forbidden for url: https://media.licdn.com/dms/image/v2/D4E03AQHhA1NMl9r1_A/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1698670021775?e=1736985600&v=beta&t=pW0L9VLPufUGVLEFRr0uQTWCCy2IawxFmI-MCRnfw2
# Using default logo instead...
# Used default logo image instead
# Waiting 1.12 seconds...
#
# Processing image 8 of 20
# Skipping 1711055218935.jpg - File already exists
#
# Processing image 9 of 20
# Skipping 1623764166025.jpg - File already exists
#
# Processing image 10 of 20
# Skipping 1524749352258.jpg - File already exists
#
# Processing image 11 of 20
# Skipping 1698440570941.jpg - File already exists
#
# Processing image 12 of 20
# Skipping 1636367599934.jpg - File already exists
#
# Processing image 13 of 20
# Skipping 1644409524714.jpg - File already exists
#
# Processing image 14 of 20
# Skipping 1707989867377.jpg - File already exists
#
# Processing image 15 of 20
# Skipping 1663103419246.jpg - File already exists
#
# Processing image 16 of 20
# Skipping 1729628087882.jpg - File already exists
#
# Processing image 17 of 20
# Skipping 1538563255048.jpg - File already exists
#
# Processing image 18 of 20
# Skipping 1584173753294.jpg - File already exists
#
# Processing image 19 of 20
# Skipping 1700953683850.jpg - File already exists
#
# Processing image 20 of 20
# Skipping 1634303036749.jpg - File already exists
#
# Download Summary:
# Total URLs processed: 20
# Successfully downloaded: 0
# Default logo used: 1
# Skipped (already existed): 19
# Failed: 0

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(save_folder) if isfile(join(save_folder, f))]

# %%
image_dict = {}

for f in onlyfiles:
    id = f .replace(".jpg", "")
    new_path_f = save_folder + "/" + f
    for p in image_links:
        if id in p:
            image_dict[p] = new_path_f
            break

# %%
len(image_dict) == len(image_links)
# Out:
# True

# %%
for i in range(len(json_dict['review'])):
    old_value = json_dict['review'][i]['profile_image_link']
    json_dict['review'][i]['profile_image_link'] = image_dict[old_value]

# %%
def decode_unicode_dict(obj):
    if isinstance(obj, dict):
        return {key: decode_unicode_dict(value) for key, value in obj.items()}
    elif isinstance(obj, list):
        return [decode_unicode_dict(element) for element in obj]
    elif isinstance(obj, str):
        # Using encode/decode to handle Unicode escape sequences
        try:
            return obj.encode('latin-1').decode('utf-8')
        except UnicodeEncodeError:
            # If it's already properly decoded, return as is
            return obj
    else:
        return obj

# %%
json_dict_decoded = decode_unicode_dict(json_dict)

# %%
with open('collected_data.json', 'w', encoding='utf-8') as outfile:
    json.dump(json_dict_decoded, outfile, ensure_ascii=False, indent=2)

# %%
print(json.dumps(json_dict_decoded, ensure_ascii=False, indent=2))
# Out:
# {
#   "review": [
#     {
#       "content": "I worked with Paolo at KNIME for almost 6 years, and you could not ask for a more passionate and knowledgeable teammate and advisor. Beyond that, he was meticulously organized about the many projects he was responsible for, and had a knack for clearly communicating advanced data science concepts to a wide variety of audiences. From a technical perspective he was always on point. I can recommend him without hesitation.",
#       "author": "Scott Fincher",
#       "author_link": "https://www.linkedin.com/in/scottfincher",
#       "role": "Data Science Community Team Lead at KNIME",
#       "profile_image_link": "reviews_images_avatars/1700444650829.jpg"
#     },
#     {
#       "content": "I had the pleasure of working closely with Paolo for the better part of a year in KNIME's Educators Alliance team. Paolo is an exceptional data scientist with a passion for problem-solving and a drive to explore uncharted territory. His unique blend of technical expertise and creativity sets him apart and has helped him succeed in multiple projects with researchers and educators. He approaches projects with enthusiasm and dedication, always striving to deliver results of the highest quality. But what truly distinguishes Paolo is his ability to effectively communicate his findings to both technical and non-technical folks in writing and presenting. In summary, I wholeheartedly recommend Paolo for data science roles at the cutting edge, in which technical expertise and analytical prowess are required.",
#       "author": "Stefan Helfrich",
#       "author_link": "https://www.linkedin.com/in/stefanhelfrich",
#       "role": "Team Lead Educators Alliance at KNIME",
#       "profile_image_link": "reviews_images_avatars/1517286449740.jpg"
#     },
#     {
#       "content": "I worked with Paolo for 6 years as part of the same team, if you're looking for a driven data expert who is always ahead of the curve, look no further!",
#       "author": "Casiana Rîmbu",
#       "author_link": "https://www.linkedin.com/in/casiana-r%C3%AImbu-7450b7153",
#       "role": "1st degree connection",
#       "profile_image_link": "reviews_images_avatars/1517019548162.jpg"
#     },
#     {
#       "content": "Paolo worked as a senior data scientist for the data science evangelism group at KNIME. He worked as the main workflow and component builder on key advanced topics, such as autoML, XAI, Python integration, and GenAI. Paolo is meticulous in his work, very motivated in implementing new ideas, organized, competent, and always curious in the most advanced data science techniques. He has also acted as a great mentor for all our new hires.",
#       "author": "Rosaria Silipo",
#       "author_link": "https://www.linkedin.com/in/rosaria",
#       "role": "Head of Data Science Evangelism at KNIME",
#       "profile_image_link": "reviews_images_avatars/1549211827567.jpg"
#     },
#     {
#       "content": "During Paolo Tamagniniâ€™s research internship at NYU, he reported to me on two key projects: â€˜Rivelo,â€™ a tool for visualizing counterfactual explanations, and a Python package for visualizing partial dependence plots. His innovative approach and commitment significantly advanced our research. Paoloâ€™s ability to grasp complex concepts and bring fresh ideas was invaluable. I strongly recommend him as he would be an asset to any team or project.",
#       "author": "Josua Krause, Ph.D.",
#       "author_link": "https://www.linkedin.com/in/josuakrause",
#       "role": "Manager",
#       "profile_image_link": "reviews_images_avatars/1529332164858.jpg"
#     },
#     {
#       "content": "Since my first days at KNIME, Paolo has always been a steady presence. Not only as an advocate and representative of the company, but also always very involved in understanding the product development and with an eye to client feedback. He always brought positive energy and made sure to efficiently communicate with me and others any issues, client feedback and more, always in a direct, precise and helpful way. Not to mention, he always had a moment, during public events or in our daily work life, to listen to feedback, questions, and report issues and positive experiences. Also, his ability to successfully lead many KNIME events is obvious when seeing the positive impact of those events and how much of a trusted figure Paolo is. I really believe that Paolo is a dedicated and strong team player, an efficient communicator and great at public relations. I will sincerely miss working with him!",
#       "author": "Luisa Barbero",
#       "author_link": "https://www.linkedin.com/in/luisabarbero",
#       "role": "UX/UI Designer I Communication Designer",
#       "profile_image_link": "reviews_images_avatars/1721652770867.jpg"
#     },
#     {
#       "content": "Paolo has been an absolute pleasure to work with. One of the most striking aspects of his professional skill set is his deep understanding of how companies can harness the power of data for strategic advantage. In addition, his knowledge of how to harness the power of low-code tools (especially KNIME) is second to none. But he is not afraid to combine this with his knowledge of pure Python when needed. His exceptional ability to demystify complex data science processes is what really sets Paolo apart. He has a unique talent for making these processes easily understandable to a broader audience, which is invaluable in collaborative and cross-functional environments. I sincerely look forward to the opportunity to work with Paolo again in the near future. He would be an asset to any team or project focused on data science and analytics with his blend of expertise, innovation, and communication skills. For any organization looking to leverage data science for business growth and efficiency, I highly recommend him.",
#       "author": "Pablo Osinaga",
#       "author_link": "https://www.linkedin.com/in/pablo-osinaga",
#       "role": "Infrastructure Engineer at DeepL",
#       "profile_image_link": "reviews_images_avatars/1698670021775.jpg"
#     },
#     {
#       "content": "Paolo is an excellent coworker, always attentive and with ideas or suggestions to add. At KNIME, he wore many different hats (workflow developer, course creator, webinar presenter and host, teacher, among others) and always executed his tasks with excellence. I'm sure that whatever he ends up doing next will be done with his usual attention to detail and care!",
#       "author": "Aline Bessa",
#       "author_link": "https://www.linkedin.com/in/alinebessa",
#       "role": "Data Scientist at KNIME",
#       "profile_image_link": "reviews_images_avatars/1711055218935.jpg"
#     },
#     {
#       "content": "When I had the pleasure of working with Paolo where he showed me how to create a KNIME verified component, he really impressed me with his attention to detail, strong technical expertise and his ability to 'make noise' and advertise his projects adequately to the intended audience. If you want to learn something, I can highly recommend taking on a project together with Paolo!",
#       "author": "Lukas Siedentop",
#       "author_link": "https://www.linkedin.com/in/lukas-siedentop",
#       "role": "Solution Engineer bei KNIME",
#       "profile_image_link": "reviews_images_avatars/1623764166025.jpg"
#     },
#     {
#       "content": "I had the pleasure of working with Paolo for almost six years at KNIME. We run several events together, teaching advanced analytics concepts to the open source community. He impressed me over and over again, not only with his vast knowledge on all things machine learning, but also with his ability to explain complex topics in a simple manner. Whenever new trends in the field of AI came up, Paolo was a trusted advisor to teams across the entire organization and the open source community. I would recommend Paolo to anyone looking for a seasoned data scientist.",
#       "author": "Marten Kose",
#       "author_link": "https://www.linkedin.com/in/marten-kose-89b399157",
#       "role": "Practice Lead - Professional Services at KNIME",
#       "profile_image_link": "reviews_images_avatars/1524749352258.jpg"
#     },
#     {
#       "content": "Working with Paolo during my time at Sapienza was a core part of my academic journey, thanks to his exceptional dedication and skills. I learned a great deal from him, owing to his ability to blend deep technical insights with a comprehensive understanding of the data science landscape. His work at KNIME demonstrates a similar impact on the broader community, highlighting his ability to advance the field through research, innovation, and collaboration. Paolo's technical expertise and broad approach to problem-solving make him a great asset to any data science team or project.",
#       "author": "Benedetto Jacopo Buratti",
#       "author_link": "https://www.linkedin.com/in/benedetto-jacopo-buratti-489884a3",
#       "role": "Autonomous Agents @ Datadog | Generative AI, Large Language Models",
#       "profile_image_link": "reviews_images_avatars/1698440570941.jpg"
#     },
#     {
#       "content": "I have worked with Paolo on multiple occasions. He pays attention to detail in his tasks and has mentored me in producing quality work as well. As a fellow team member, I always enjoyed working with him. Paolo is a quick learner and has the capability to tackle challenges with ease. He is technically a sound data scientist and a well-rounded professional. It is inspirational for me in how he takes ownership at work and therefore earns my highest recommendation.",
#       "author": "Ali Asghar Marvi",
#       "author_link": "https://www.linkedin.com/in/aamarvi",
#       "role": "Data Scientist at KNIME",
#       "profile_image_link": "reviews_images_avatars/1636367599934.jpg"
#     },
#     {
#       "content": "Collaborating closely with Paolo on building the Parameter Optimization component and creating a complete XAI space for KNIME was a pleasure. One of Paolo's standout qualities is his attention to detail and ability to explain complex theories in simple terms, which was very important in writing the booklet on using XAI with KNIME. Paolo possesses not only amazing talent but also demonstrates proactive leadership qualities. I endorse him for any opportunity.",
#       "author": "Keerthan Shetty",
#       "author_link": "https://www.linkedin.com/in/keerthan-shetty-4b009a18",
#       "role": "Jr Data Scientist at KNIME (Part Time)",
#       "profile_image_link": "reviews_images_avatars/1644409524714.jpg"
#     },
#     {
#       "content": "Iâ€™ve been lucky to work with Paolo and watch his dedication to whatever he works on. Heâ€™s my go-to person for data science questions, as well as really insightful about what people want and need when interacting with technology. Genuine, smart and great at presenting complex topics in simple terms!",
#       "author": "Karen Abraham",
#       "author_link": "https://www.linkedin.com/in/k-abraham",
#       "role": "1st degree connection",
#       "profile_image_link": "reviews_images_avatars/1707989867377.jpg"
#     },
#     {
#       "content": "I had the pleasure of collaborating with Paolo on several data science projects at KNIME. Paolo is an incredibly motivated individual, detail-oriented and goal-driven. As a natural leader, he effectively communicates his thoughts throughout the team and has a knack for simplifying complex concepts, making them easily understandable. Paolo is adept at multitasking and exhibits excellent organizational skills; his Trello board stands out as the cleanest and most organized I've encountered. He would be a valuable addition to any team!",
#       "author": "Jinwei Sun",
#       "author_link": "https://www.linkedin.com/in/jinweis",
#       "role": "MS Student in Data Science at University of San Francisco",
#       "profile_image_link": "reviews_images_avatars/1663103419246.jpg"
#     },
#     {
#       "content": "What I admire most about Paolo is that he is passionate. He strives for high quality work at all times. When in a group his main priority is always making sure we are delivering the best product possible. When I worked with Paolo he went out of his way to make me feel welcome and always made time to mentor me when I did not know how to move forward in a project. I appreciated this most of all. It is a rare gift to find someone who not only wants to help but can lead by example. His talent for communication is not only interpersonal, but extends to the lectures he provides at conferences or online. He understands complex concepts and knows how to clearly and engagingly relay that knowledge to various levels of expertise. Paolo personally taught not only how to make my work better, but how to show it to the world in a way I could be proud of.",
#       "author": "Victor Palacios",
#       "author_link": "https://www.linkedin.com/in/victorapalacios",
#       "role": "Director of Data Science Partnerships",
#       "profile_image_link": "reviews_images_avatars/1729628087882.jpg"
#     },
#     {
#       "content": "I had the pleasure of closely collaborating with Paolo on developing topic modeling components. Throughout our work together, I was impressed by his remarkable ability to grasp complex analytical concepts and effectively communicate them.",
#       "author": "Francesco Tuscolano",
#       "author_link": "https://www.linkedin.com/in/francesco-tuscolano-06549397",
#       "role": "1st",
#       "profile_image_link": "reviews_images_avatars/1538563255048.jpg"
#     },
#     {
#       "content": "Paolo was a great colleague who I will miss a lot working with. I always appreciated his work attitude, creative ideas and honest but very intelligent and constructive input and feedback on our product development. I especially liked that a good outcome for our users was always the center of his motivation. Paolo was remarkable good in explaining complicated subjects in a easy to understand and engaging way, not only internally but also in his teaching courses to our users. No doubts Paolo will be a great addition to any team! All the best!",
#       "author": "Tobias Schmidt",
#       "author_link": "https://www.linkedin.com/in/tobias-s-38478233",
#       "role": "1st",
#       "profile_image_link": "reviews_images_avatars/1584173753294.jpg"
#     },
#     {
#       "content": "Really delighted to work with Paolo for two years in many different fields in Data Science. He can bring value to any company, both personally and professionally.",
#       "author": "José Alberto Gallardo Pérez",
#       "author_link": "https://www.linkedin.com/in/jos%C3%A9-alberto-gallardo-p%C3%A9rez",
#       "role": "Data Scientist at KNIME | Tech Youtuber | Computer Engineer",
#       "profile_image_link": "reviews_images_avatars/1700953683850.jpg"
#     },
#     {
#       "content": "I had the privilege of collaborating with Paolo on several data science projects while working at KNIME in Berlin, and I can attest to his exceptional skills in this field. Paolo has a remarkable ability to quickly grasp new concepts, which is paramount in the rapidly evolving landscape of data science. His adeptness at understanding complex algorithms and methodologies is truly impressive. One of Paolo's standout qualities is his knack for translating data insights into actionable strategies. He has a keen eye for identifying opportunities to leverage data science in product conceptualization, showcasing his innovative thinking and business acumen. His contributions were instrumental in shaping the direction of our projects and driving them towards success. In addition to his technical prowess, Paolo is also a natural leader. He provided clear guidance and direction to our team, ensuring that everyone stayed aligned with our objectives. His leadership style is both empowering and collaborative, fostering a positive and productive work environment.",
#       "author": "Mahantesh Pattadkal",
#       "author_link": "https://www.linkedin.com/in/mahantesh-pattadkal-7a2607101",
#       "role": "Sr. Data Scientist @Baxter | KNIMEr | Ex Mu Sigma | M.S Data Science",
#       "profile_image_link": "reviews_images_avatars/1634303036749.jpg"
#     }
#   ]
# }
